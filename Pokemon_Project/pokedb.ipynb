# %%
import sqlite3 as sql
import pandas as pd

# %%
poke_df = pd.read_csv("..\Pokemon_Project\CSV\Pokemon_DB_Clean.csv", encoding = "ISO-8859-1")

# %%
poke_df
# Out:
#       Pokemon Id  Pokedex Number Pokemon Name       Classification  \
# 0              1               1    Bulbasaur         Seed Pokemon
# 1              2               2      Ivysaur         Seed Pokemon
# 2              3               3     Venusaur         Seed Pokemon
# 3              4               3     Venusaur         Seed Pokemon
# 4              5               4   Charmander       Lizard Pokemon
# ...          ...             ...          ...                  ...
# 1071        1601             892      Urshifu        Wushu Pokemon
# 1072        1602             896    Glastrier   Wild Horse Pokemon
# 1073        1603             897    Spectrier  Swift Horse Pokemon
# 1074        1604             898      Calyrex    High King Pokemon
# 1075        1605             898      Calyrex    High King Pokemon
#
#           Alternate Form Name  Original Pokemon ID Legendary Type  \
# 0                         NaN                  NaN            NaN
# ...

# %%
poke_types = pd.read_csv("..\Pokemon_Project\CSV\Types.csv", encoding = "ISO-8859-1")
regions = pd.read_csv("..\Pokemon_Project\CSV\Regions.csv", encoding = "ISO-8859-1")
games = pd.read_csv("..\Pokemon_Project\CSV\Games.csv", encoding = "ISO-8859-1")
egg_groups = pd.read_csv("..\Pokemon_Project\CSV\Egg_Groups.csv", encoding = "ISO-8859-1")
abilities =pd.read_csv("..\Pokemon_Project\CSV\Abilities.csv", encoding = "ISO-8859-1")

# %%
abilities.set_index("RecordID",inplace=True)
abilities
# Out:
#                Ability                                        Description
# RecordID
# 1         Adaptability   Powers up moves of the same type as the PokÃ©mon
# 2             Aerilate  Normaltype moves become Flyingtype moves The p...
# 3            Aftermath  Damages the attacker if it contacts the PokÃ©m...
# 4             Air Lock                  Eliminates the effects of weather
# 5             Analytic     Boosts move power when the PokÃ©mon moves last
# ...                ...                                                ...
# 263        White Smoke  The PokÃ©mon is protected by its white smoke w...
# 264           Wimp Out  The PokÃ©mon cowardly switches out when its HP...
# 265       Wonder Guard  Its mysterious power only lets supereffective ...
# 266        Wonder Skin             Makes status moves more likely to miss
# 267           Zen Mode  Changes the PokÃ©mons shape when HP is half or...
#
# [267 rows x 2 columns]

# %%
egg_groups.set_index("RecordID", inplace=True)

# %%
egg_groups
# Out:
#              Egg Group
# RecordID
# 1            Amorphous
# 2                  Bug
# 3                Ditto
# 4               Dragon
# 5                Fairy
# 6                Field
# 7               Flying
# 8                Grass
# 9            HumanLike
# 10             Mineral
# 11             Monster
# 12                 NaN
# 13        Undiscovered
# 14             Water 1
# 15             Water 2
# 16             Water 3

# %%
games.set_index("RecordID", inplace=True)
games
# Out:
#          Game(s) of Origin
# RecordID
# 1                    Black
# 2                  Black 2
# 3                  Diamond
# 4                  Emerald
# 5                 Fire Red
# 6                     Gold
# 7               Leaf Green
# 8          Lets Go Pikachu
# 9               Omega Ruby
# 10                Platinum
# 11                     Red
# 12                    Ruby
# 13                     Sun
# 14                   Sword
# 15               Ultra Sun
# 16                       X

# %%
regions.set_index("RecordID", inplace=True)

# %%
regions
# Out:
#          Region of Origin
# RecordID
# 1                   Alola
# 2                   Galar
# 3                   Hoenn
# 4                   Johto
# 5                   Kalos
# 6                   Kanto
# 7                  Sinnoh
# 8                   Unova

# %%
poke_types.set_index("RecordID", inplace=True)
poke_types
# Out:
#               Type
# RecordID
# 1              Bug
# 2             Dark
# 3           Dragon
# 4         Electric
# 5            Fairy
# 6         Fighting
# 7             Fire
# 8           Flying
# 9            Ghost
# 10           Grass
# 11          Ground
# 12             Ice
# 13          Normal
# 14          Poison
# 15         Psychic
# 16            Rock
# 17           Steel
# 18           Water

# %%
sql_db = sql.connect("pokeDB.db")

# %%
poke_types.to_sql("Types", sql_db)
# Out:
# 18

# %%
cur = sql_db.cursor()

# %%
cur.execute("SELECT * FROM Types")

# %%
cur.fetchall()
# Out:
# [(1, 'Bug'),
#  (2, 'Dark'),
#  (3, 'Dragon'),
#  (4, 'Electric'),
#  (5, 'Fairy'),
#  (6, 'Fighting'),
#  (7, 'Fire'),
#  (8, 'Flying'),
#  (9, 'Ghost'),
#  (10, 'Grass'),
#  (11, 'Ground'),
#  (12, 'Ice'),
#  (13, 'Normal'),
#  (14, 'Poison'),
#  (15, 'Psychic'),
#  (16, 'Rock'),
#  (17, 'Steel'),
#  (18, 'Water')]

# %%
regions.to_sql("Regions", sql_db)
games.to_sql("Games", sql_db)
egg_groups.to_sql("EggGroups", sql_db)
abilities.to_sql("Abilities", sql_db)
# Out:
# 267

# %%
cur.execute("SELECT * FROM abilities")
cur.fetchall()
# Out:
# [(1, 'Adaptability', 'Powers up moves of the same type as the Pokï¿½mon'),
#  (2,
#   'Aerilate',
#   'Normaltype moves become Flyingtype moves The power of those moves is boosted a little'),
#  (3,
#   'Aftermath',
#   'Damages the attacker if it contacts the Pokï¿½mon with a finishing hit'),
#  (4, 'Air Lock', 'Eliminates the effects of weather'),
#  (5, 'Analytic', 'Boosts move power when the Pokï¿½mon moves last'),
#  (6,
#   'Anger Point',
#   'The Pokï¿½mon is angered when it takes a critical hit and that maxes its Attack stat'),
#  (7,
#   'Anticipation',
#   'The Pokï¿½mon can sense an opposing Pokï¿½mons dangerous moves'),
#  (8, 'Arena Trap', 'Prevents opposing Pokï¿½mon from fleeing'),
#  (9,
#   'Aroma Veil',
#   'Protects itself and its allies from attacks that limit their move choices'),
#  (10,
#   'As One',
#   'This Ability combines the effects of both Calyrexs Unnerve Ability and GlastriersSpectriers Chilling NeighGrim Neigh Ability'),
#  (11,
#   'Aura Break',
# ...

# %%
cur.execute("DROP TABLE abilities")

# %%
abilities.to_sql("Abilities", sql_db)
# Out:
# 267

# %%
cur.execute("SELECT * FROM abilities")
cur.fetchall()
# Out:
# [(1, 'Adaptability', 'Powers up moves of the same type as the PokÃ©mon'),
#  (2,
#   'Aerilate',
#   'Normaltype moves become Flyingtype moves The power of those moves is boosted a little'),
#  (3,
#   'Aftermath',
#   'Damages the attacker if it contacts the PokÃ©mon with a finishing hit'),
#  (4, 'Air Lock', 'Eliminates the effects of weather'),
#  (5, 'Analytic', 'Boosts move power when the PokÃ©mon moves last'),
#  (6,
#   'Anger Point',
#   'The PokÃ©mon is angered when it takes a critical hit and that maxes its Attack stat'),
#  (7,
#   'Anticipation',
#   'The PokÃ©mon can sense an opposing PokÃ©mons dangerous moves'),
#  (8, 'Arena Trap', 'Prevents opposing PokÃ©mon from fleeing'),
#  (9,
#   'Aroma Veil',
#   'Protects itself and its allies from attacks that limit their move choices'),
#  (10,
#   'As One',
#   'This Ability combines the effects of both Calyrexs Unnerve Ability and GlastriersSpectriers Chilling NeighGrim Neigh Ability'),
#  (11,
#   'Aura Break',
# ...

# %%
sql.version
# Out:
# '2.6.0'

# %%
poke_df.rename(columns={"ï»¿Pokemon Id":"Pokemon Id"}, inplace=True)

# %%
poke_df.set_index("Pokemon Id", inplace=True)

# %%
poke_df
# Out:
#             Pokedex Number Pokemon Name       Classification  \
# Pokemon Id
# 1                        1    Bulbasaur         Seed Pokemon
# 2                        2      Ivysaur         Seed Pokemon
# 3                        3     Venusaur         Seed Pokemon
# 4                        3     Venusaur         Seed Pokemon
# 5                        4   Charmander       Lizard Pokemon
# ...                    ...          ...                  ...
# 1601                   892      Urshifu        Wushu Pokemon
# 1602                   896    Glastrier   Wild Horse Pokemon
# 1603                   897    Spectrier  Swift Horse Pokemon
# 1604                   898      Calyrex    High King Pokemon
# 1605                   898      Calyrex    High King Pokemon
#
#                 Alternate Form Name  Original Pokemon ID Legendary Type  \
# Pokemon Id
# 1                               NaN                  NaN            NaN
# ...

# %%
test_df = poke_df.copy()

# %%
test_df
# Out:
#             Pokedex Number Pokemon Name       Classification  \
# Pokemon Id
# 1                        1    Bulbasaur         Seed Pokemon
# 2                        2      Ivysaur         Seed Pokemon
# 3                        3     Venusaur         Seed Pokemon
# 4                        3     Venusaur         Seed Pokemon
# 5                        4   Charmander       Lizard Pokemon
# ...                    ...          ...                  ...
# 1601                   892      Urshifu        Wushu Pokemon
# 1602                   896    Glastrier   Wild Horse Pokemon
# 1603                   897    Spectrier  Swift Horse Pokemon
# 1604                   898      Calyrex    High King Pokemon
# 1605                   898      Calyrex    High King Pokemon
#
#                 Alternate Form Name  Original Pokemon ID Legendary Type  \
# Pokemon Id
# 1                               NaN                  NaN            NaN
# ...

# %%
poke_types.set_index("RecordID")
# Out:
#               Type
# RecordID
# 1              Bug
# 2             Dark
# 3           Dragon
# 4         Electric
# 5            Fairy
# 6         Fighting
# 7             Fire
# 8           Flying
# 9            Ghost
# 10           Grass
# 11          Ground
# 12             Ice
# 13          Normal
# 14          Poison
# 15         Psychic
# 16            Rock
# 17           Steel
# 18           Water

# %%
test_df["Primary Type"] = test_df["Primary Type"].map(poke_types.set_index("Type")['RecordID'])

# %%
test_df
# Out:
#             Pokedex Number Pokemon Name       Classification  \
# Pokemon Id
# 1                        1    Bulbasaur         Seed Pokemon
# 2                        2      Ivysaur         Seed Pokemon
# 3                        3     Venusaur         Seed Pokemon
# 4                        3     Venusaur         Seed Pokemon
# 5                        4   Charmander       Lizard Pokemon
# ...                    ...          ...                  ...
# 1601                   892      Urshifu        Wushu Pokemon
# 1602                   896    Glastrier   Wild Horse Pokemon
# 1603                   897    Spectrier  Swift Horse Pokemon
# 1604                   898      Calyrex    High King Pokemon
# 1605                   898      Calyrex    High King Pokemon
#
#                 Alternate Form Name  Original Pokemon ID Legendary Type  \
# Pokemon Id
# 1                               NaN                  NaN            NaN
# ...

# %%
test_df["Secondary Type"] = test_df["Secondary Type"].map(poke_types.set_index("Type")['RecordID'])

# %%
test_df
# Out:
#             Pokedex Number Pokemon Name       Classification  \
# Pokemon Id
# 1                        1    Bulbasaur         Seed Pokemon
# 2                        2      Ivysaur         Seed Pokemon
# 3                        3     Venusaur         Seed Pokemon
# 4                        3     Venusaur         Seed Pokemon
# 5                        4   Charmander       Lizard Pokemon
# ...                    ...          ...                  ...
# 1601                   892      Urshifu        Wushu Pokemon
# 1602                   896    Glastrier   Wild Horse Pokemon
# 1603                   897    Spectrier  Swift Horse Pokemon
# 1604                   898      Calyrex    High King Pokemon
# 1605                   898      Calyrex    High King Pokemon
#
#                 Alternate Form Name  Original Pokemon ID Legendary Type  \
# Pokemon Id
# 1                               NaN                  NaN            NaN
# ...

# %%
test_df = test_df.drop('Primary Ability Description', axis=1)
test_df = test_df.drop('Secondary Ability Description', axis=1)

# %%
test_df = test_df.drop("Hidden Ability Description", axis=1)

# %%
test_df["Primary Egg Group"] = test_df["Primary Egg Group"].map(egg_groups.set_index("Egg Group")['RecordID'])

# %%
games
# Out:
#     RecordID Game(s) of Origin
# 0          1             Black
# 1          2           Black 2
# 2          3           Diamond
# 3          4           Emerald
# 4          5          Fire Red
# 5          6              Gold
# 6          7        Leaf Green
# 7          8   Lets Go Pikachu
# 8          9        Omega Ruby
# 9         10          Platinum
# 10        11               Red
# 11        12              Ruby
# 12        13               Sun
# 13        14             Sword
# 14        15         Ultra Sun
# 15        16                 X

# %%
test_df["Secondary Egg Group"] = test_df["Secondary Egg Group"].map(egg_groups.set_index("Egg Group")['RecordID'])

# %%
test_df["Game(s) of Origin"] = test_df["Game(s) of Origin"].map(games.set_index("Game(s) of Origin")['RecordID'])

# %%
test_df["Region of Origin"] = test_df["Region of Origin"].map(regions.set_index("Region of Origin")['RecordID'])

# %%
test_df["Region of Origin"]
# Out:
# Pokemon Id
# 1       6
# 2       6
# 3       6
# 4       5
# 5       6
#        ..
# 1601    2
# 1602    2
# 1603    2
# 1604    2
# 1605    2
# Name: Region of Origin, Length: 1076, dtype: int64

# %%
regions.rename(columns={"ï»¿RecordID":"RecordID"}, inplace=True)

# %%
column_names = list(test_df.columns)

# %%
test_df
# Out:
#             Pokedex Number Pokemon Name       Classification  \
# Pokemon Id
# 1                        1    Bulbasaur         Seed Pokemon
# 2                        2      Ivysaur         Seed Pokemon
# 3                        3     Venusaur         Seed Pokemon
# 4                        3     Venusaur         Seed Pokemon
# 5                        4   Charmander       Lizard Pokemon
# ...                    ...          ...                  ...
# 1601                   892      Urshifu        Wushu Pokemon
# 1602                   896    Glastrier   Wild Horse Pokemon
# 1603                   897    Spectrier  Swift Horse Pokemon
# 1604                   898      Calyrex    High King Pokemon
# 1605                   898      Calyrex    High King Pokemon
#
#                 Alternate Form Name  Original Pokemon ID Legendary Type  \
# Pokemon Id
# 1                               NaN                  NaN            NaN
# ...

# %%
db_data_types = []
for col in test_df:
    db_data_types.append(test_df.iloc[[4]][col].apply(type))

# %%
import re

# %%
column_regex = r':\s(.*),'

# %%
type_regex = r"'(\w+)'"

# %%
column_types =[]

# %%
for col in test_df:
    db_data_types.append(test_df.iloc[[4]][col].apply(type))

# %%
db_data_types_strings = [str(x) for x in db_data_types]

# %%
re.findall(type_regex,db_data_types_strings[1])[0]
# Out:
# 'str'

# %%
re.findall(column_regex,db_data_types_strings[0])[0]
# Out:
# 'Pokedex Number'

# %%
db_columns_types = {re.findall(column_regex,x)[0]: re.findall(type_regex,x)[0] for x in db_data_types_strings }

# %%
db_columns_types
# Out:
# {'Pokedex Number': 'int',
#  'Pokemon Name': 'str',
#  'Classification': 'str',
#  'Alternate Form Name': 'float',
#  'Original Pokemon ID': 'float',
#  'Legendary Type': 'float',
#  'Pokemon Height': 'int',
#  'Pokemon Weight': 'int',
#  'Primary Type': 'int',
#  'Secondary Type': 'float',
#  'Primary Ability': 'str',
#  'Secondary Ability': 'float',
#  'Hidden Ability': 'str',
#  'Special Event Ability': 'float',
#  'Special Event Ability Description': 'float',
#  'Male Ratio': 'int',
#  'Female Ratio': 'int',
#  'Base Happiness': 'int',
#  'Game(s) of Origin': 'int',
#  'Region of Origin': 'int',
#  'Health Stat': 'int',
#  'Attack Stat': 'int',
#  'Defense Stat': 'int',
#  'Special Attack Stat': 'int',
#  'Special Defense Stat': 'int',
#  'Speed Stat': 'int',
#  'Health EV': 'int',
#  'Attack EV': 'int',
#  'Defense EV': 'int',
#  'Special Attack EV': 'int',
#  'Special Defense EV': 'int',
#  'Speed EV': 'int',
#  'Catch Rate': 'int',
#  'Experience Growth': 'str',
# ...

# %%
test_df["Primary Ability"]
# Out:
# Pokemon Id
# 1             Overgrow
# 2             Overgrow
# 3             Overgrow
# 4            Thick Fat
# 5                Blaze
#              ...
# 1601       Unseen Fist
# 1602    Chilling Neigh
# 1603        Grim Neigh
# 1604            As One
# 1605            As One
# Name: Primary Ability, Length: 1076, dtype: object

# %%
test_df["Primary Ability"] = test_df["Primary Ability"].map(abilities.reset_index().set_index("Ability")['RecordID'])

# %%
test_df["Primary Ability"]
# Out:
# Pokemon Id
# 1       144
# 2       144
# 3       144
# 4       240
# 5        20
#        ...
# 1601    253
# 1602     23
# 1603     77
# 1604     10
# 1605     10
# Name: Primary Ability, Length: 1076, dtype: int64

# %%
test_df["Secondary Ability"] = test_df["Secondary Ability"].map(abilities.reset_index().set_index("Ability")['RecordID'])

# %%
test_df["Secondary Ability"]
# Out:
# Pokemon Id
# 1       136
# 2       136
# 3       136
# 4       136
# 5       136
#        ...
# 1601    136
# 1602    136
# 1603    136
# 1604    136
# 1605    136
# Name: Secondary Ability, Length: 1076, dtype: int64

# %%
abilities.iloc[[135]]
# Out:
#          Ability Description
# RecordID
# 136          NaN         NaN

# %%
test_df
# Out:
#             Pokedex Number Pokemon Name       Classification  \
# Pokemon Id
# 1                        1    Bulbasaur         Seed Pokemon
# 2                        2      Ivysaur         Seed Pokemon
# 3                        3     Venusaur         Seed Pokemon
# 4                        3     Venusaur         Seed Pokemon
# 5                        4   Charmander       Lizard Pokemon
# ...                    ...          ...                  ...
# 1601                   892      Urshifu        Wushu Pokemon
# 1602                   896    Glastrier   Wild Horse Pokemon
# 1603                   897    Spectrier  Swift Horse Pokemon
# 1604                   898      Calyrex    High King Pokemon
# 1605                   898      Calyrex    High King Pokemon
#
#                 Alternate Form Name  Original Pokemon ID Legendary Type  \
# Pokemon Id
# 1                               NaN                  NaN            NaN
# ...

# %%
test_df["Hidden Ability"] = test_df["Hidden Ability"].map(abilities.reset_index().set_index("Ability")['RecordID'])

# %%
test_df["Hidden Ability"]
# Out:
# Pokemon Id
# 1        24
# 2        24
# 3        24
# 4       136
# 5       207
#        ...
# 1601    136
# 1602    136
# 1603    136
# 1604    136
# 1605    136
# Name: Hidden Ability, Length: 1076, dtype: int64

# %%
test_df["Special Event Ability"] = test_df["Special Event Ability"].map(abilities.reset_index().set_index("Ability")['RecordID'])

# %%
test_df.drop("Special Event Ability Description", axis=1, inplace=True)

# %%
test_df.to_sql('Pokemon', sql_db, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In [251], line 1
# ----> 1 test_df.to_sql('Pokemon', sql_db, if_exists='append')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# ...

# %%
test_df.reset_index(inplace=True)

# %%
test_df.drop("Pokemon Id", axis=1, inplace=True)

# %%
test_df.index.name = "PokemonID"

# %%
test_df
# Out:
#            Pokedex Number Pokemon Name       Classification  \
# PokemonID
# 0                       1    Bulbasaur         Seed Pokemon
# 1                       2      Ivysaur         Seed Pokemon
# 2                       3     Venusaur         Seed Pokemon
# 3                       3     Venusaur         Seed Pokemon
# 4                       4   Charmander       Lizard Pokemon
# ...                   ...          ...                  ...
# 1071                  892      Urshifu        Wushu Pokemon
# 1072                  896    Glastrier   Wild Horse Pokemon
# 1073                  897    Spectrier  Swift Horse Pokemon
# 1074                  898      Calyrex    High King Pokemon
# 1075                  898      Calyrex    High King Pokemon
#
#                Alternate Form Name  Original Pokemon ID Legendary Type  \
# PokemonID
# 0                              NaN                  NaN            NaN
# 1                              NaN                  NaN            NaN
# ...

# %%
test_df.to_sql('Pokemon', sql_db, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In [262], line 1
# ----> 1 test_df.to_sql('Pokemon', sql_db, if_exists='append')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# ...

# %%
new_column_names = 'PokedexNumber, PokemonName, Classification, AlternateFormName, OriginalPokemonID, LegendaryType, PokemonHeight, PokemonWeight, PrimaryType, SecondaryType, PrimaryAbility, SecondaryAbility, HiddenAbility, SpecialEventAbility, SpecialEventAbilityDescription, MaleRatio, FemaleRatio, BaseHappiness, GameofOrigin, RegionofOrigin, HealthStat, AttackStat, DefenseStat, SpecialAttackStat, SpecialDefenseStat, SpeedStat, HealthEV, AttackEV, DefenseEV, SpecialAttackEV, SpecialDefenseEV, SpeedEV, CatchRate, ExperienceGrowth, ExperienceGrowthTotal, ExperienceYield, PrimaryEggGroup, SecondaryEggGroup, EggCycleCount, PreEvolutionPokemonId, EvolutionDetails'.split(', ')

# %%
new_column_names
# Out:
# ['PokedexNumber',
#  'PokemonName',
#  'Classification',
#  'AlternateFormName',
#  'OriginalPokemonID',
#  'LegendaryType',
#  'PokemonHeight',
#  'PokemonWeight',
#  'PrimaryType',
#  'SecondaryType',
#  'PrimaryAbility',
#  'SecondaryAbility',
#  'HiddenAbility',
#  'SpecialEventAbility',
#  'SpecialEventAbilityDescription',
#  'MaleRatio',
#  'FemaleRatio',
#  'BaseHappiness',
#  'GameofOrigin',
#  'RegionofOrigin',
#  'HealthStat',
#  'AttackStat',
#  'DefenseStat',
#  'SpecialAttackStat',
#  'SpecialDefenseStat',
#  'SpeedStat',
#  'HealthEV',
#  'AttackEV',
#  'DefenseEV',
#  'SpecialAttackEV',
#  'SpecialDefenseEV',
#  'SpeedEV',
#  'CatchRate',
#  'ExperienceGrowth',
#  'ExperienceGrowthTotal',
#  'ExperienceYield',
#  'PrimaryEggGroup',
#  'SecondaryEggGroup',
#  'EggCycleCount',
#  'PreEvolutionPokemonId',
#  'EvolutionDetails']

# %%
test_df_final = test_df.copy()

# %%
new_column_names.remove("PokemonID")

# %%
test_df_final.columns = new_column_names

# %%
test_df_final.to_sql('Pokemon', sql_db, if_exists='append')
# Out:
# 1076
